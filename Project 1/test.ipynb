# %%
import numpy as np
import scipy.sparse as sp
import scipy.sparse.linalg as spla

test = sp.eye(5, format='csr')+sp.eye(5,k=-4, format='csr')

print(test)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 5 stored elements and shape (5, 5)>
#   Coords	Values
#   (0, 0)	1.0
#   (1, 1)	1.0
#   (2, 2)	1.0
#   (3, 3)	1.0
#   (4, 4)	1.0
